# %%
import os
import time
from selenium import webdriver



    


def iter_png (path) :
    names = []
    for fn in os.listdir(path):
         if  os.path.isfile(path+'/'+fn)  :
            if fn.split('.')[-1]=='html' :
                names+=[fn]
         else :
            if path =='.' :
                iter_png (fn)
            else :
                iter_png (path+'/'+fn)
    str = path+'\n\n'
    str += ('<select onchange="theThingToDoIfItChange()" id="selection">\n')
    for n in names :
        n = '.'.join(n.split('.')[0:-1])
        str += '      <option value="'+n+'">'+n+'</option>\n'
    str += '</select>\n\n'
    
    str+='var dict = {\n'
    for n in names :
        n = '.'.join(n.split('.')[0:-1])
        str += '      "'+n+'": "describe '+n+'"'+',\n'
    str += '      };\n\n\n\n_______________\n'
    print (str)
         
iter_png('../docs/assets/data')
# Out:
# ../docs/assets/data/maps_partis
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="map_AdI">map_AdI</option>
#       <option value="map_DS">map_DS</option>
#       <option value="map_Lega">map_Lega</option>
#       <option value="map_MCR">map_MCR</option>
#       <option value="map_PBD">map_PBD</option>
#       <option value="map_PCS">map_PCS</option>
#       <option value="map_PDC">map_PDC</option>
#       <option value="map_PES">map_PES</option>
#       <option value="map_PEV">map_PEV</option>
#       <option value="map_PLR">map_PLR</option>
#       <option value="map_PLS">map_PLS</option>
#       <option value="map_POCH">map_POCH</option>
#       <option value="map_PRD">map_PRD</option>
#       <option value="map_PS">map_PS</option>
#       <option value="map_PSL">map_PSL</option>
#       <option value="map_PST">map_PST</option>
#       <option value="map_PVL">map_PVL</option>
#       <option value="map_Rep.">map_Rep.</option>
#       <option value="map_UDC">map_UDC</option>
#       <option value="map_UDF">map_UDF</option>
# </select>
#
# var dict = {
#       "map_AdI": "describe map_AdI",
#       "map_DS": "describe map_DS",
#       "map_Lega": "describe map_Lega",
#       "map_MCR": "describe map_MCR",
#       "map_PBD": "describe map_PBD",
#       "map_PCS": "describe map_PCS",
#       "map_PDC": "describe map_PDC",
#       "map_PES": "describe map_PES",
#       "map_PEV": "describe map_PEV",
#       "map_PLR": "describe map_PLR",
#       "map_PLS": "describe map_PLS",
#       "map_POCH": "describe map_POCH",
#       "map_PRD": "describe map_PRD",
#       "map_PS": "describe map_PS",
#       "map_PSL": "describe map_PSL",
#       "map_PST": "describe map_PST",
#       "map_PVL": "describe map_PVL",
#       "map_Rep.": "describe map_Rep.",
#       "map_UDC": "describe map_UDC",
#       "map_UDF": "describe map_UDF",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/maps_theme_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="DBSCAN_Economy">DBSCAN_Economy</option>
#       <option value="DBSCAN_Education,culture,media">DBSCAN_Education,culture,media</option>
#       <option value="DBSCAN_Foreign policy">DBSCAN_Foreign policy</option>
#       <option value="DBSCAN_Infrastructure, planning, environment">DBSCAN_Infrastructure, planning, environment</option>
#       <option value="DBSCAN_Political regime">DBSCAN_Political regime</option>
#       <option value="DBSCAN_public finances">DBSCAN_public finances</option>
#       <option value="DBSCAN_security policy">DBSCAN_security policy</option>
#       <option value="DBSCAN_social policies">DBSCAN_social policies</option>
#       <option value="kmeans_Economy">kmeans_Economy</option>
#       <option value="kmeans_Education,culture,media">kmeans_Education,culture,media</option>
#       <option value="kmeans_Foreign policy">kmeans_Foreign policy</option>
#       <option value="kmeans_Infrastructure, planning, environment">kmeans_Infrastructure, planning, environment</option>
#       <option value="kmeans_Political regime">kmeans_Political regime</option>
#       <option value="kmeans_public finances">kmeans_public finances</option>
#       <option value="kmeans_security policy">kmeans_security policy</option>
#       <option value="kmeans_social policies">kmeans_social policies</option>
# </select>
#
# var dict = {
#       "DBSCAN_Economy": "describe DBSCAN_Economy",
#       "DBSCAN_Education,culture,media": "describe DBSCAN_Education,culture,media",
#       "DBSCAN_Foreign policy": "describe DBSCAN_Foreign policy",
#       "DBSCAN_Infrastructure, planning, environment": "describe DBSCAN_Infrastructure, planning, environment",
#       "DBSCAN_Political regime": "describe DBSCAN_Political regime",
#       "DBSCAN_public finances": "describe DBSCAN_public finances",
#       "DBSCAN_security policy": "describe DBSCAN_security policy",
#       "DBSCAN_social policies": "describe DBSCAN_social policies",
#       "kmeans_Economy": "describe kmeans_Economy",
#       "kmeans_Education,culture,media": "describe kmeans_Education,culture,media",
#       "kmeans_Foreign policy": "describe kmeans_Foreign policy",
#       "kmeans_Infrastructure, planning, environment": "describe kmeans_Infrastructure, planning, environment",
#       "kmeans_Political regime": "describe kmeans_Political regime",
#       "kmeans_public finances": "describe kmeans_public finances",
#       "kmeans_security policy": "describe kmeans_security policy",
#       "kmeans_social policies": "describe kmeans_social policies",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/map_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="DBSCAN">DBSCAN</option>
#       <option value="kmeans2">kmeans2</option>
#       <option value="kmeans3">kmeans3</option>
#       <option value="kmeans4">kmeans4</option>
#       <option value="kmeans5">kmeans5</option>
# </select>
#
# var dict = {
#       "DBSCAN": "describe DBSCAN",
#       "kmeans2": "describe kmeans2",
#       "kmeans3": "describe kmeans3",
#       "kmeans4": "describe kmeans4",
#       "kmeans5": "describe kmeans5",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/map_recommendation_cluster
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="DBSCAN_AdI">DBSCAN_AdI</option>
#       <option value="DBSCAN_DS">DBSCAN_DS</option>
#       <option value="DBSCAN_Lega">DBSCAN_Lega</option>
#       <option value="DBSCAN_MCR">DBSCAN_MCR</option>
#       <option value="DBSCAN_PBD">DBSCAN_PBD</option>
#       <option value="DBSCAN_PCS">DBSCAN_PCS</option>
#       <option value="DBSCAN_PDC">DBSCAN_PDC</option>
#       <option value="DBSCAN_PES">DBSCAN_PES</option>
#       <option value="DBSCAN_PEV">DBSCAN_PEV</option>
#       <option value="DBSCAN_PLR">DBSCAN_PLR</option>
#       <option value="DBSCAN_PLS">DBSCAN_PLS</option>
#       <option value="DBSCAN_POCH">DBSCAN_POCH</option>
#       <option value="DBSCAN_PRD">DBSCAN_PRD</option>
#       <option value="DBSCAN_PS">DBSCAN_PS</option>
#       <option value="DBSCAN_PSL">DBSCAN_PSL</option>
#       <option value="DBSCAN_PST">DBSCAN_PST</option>
#       <option value="DBSCAN_PVL">DBSCAN_PVL</option>
#       <option value="DBSCAN_Rep.">DBSCAN_Rep.</option>
#       <option value="DBSCAN_UDC">DBSCAN_UDC</option>
#       <option value="DBSCAN_UDF">DBSCAN_UDF</option>
#       <option value="kmeans_AdI">kmeans_AdI</option>
#       <option value="kmeans_DS">kmeans_DS</option>
#       <option value="kmeans_Lega">kmeans_Lega</option>
#       <option value="kmeans_MCR">kmeans_MCR</option>
#       <option value="kmeans_PBD">kmeans_PBD</option>
#       <option value="kmeans_PCS">kmeans_PCS</option>
#       <option value="kmeans_PDC">kmeans_PDC</option>
#       <option value="kmeans_PES">kmeans_PES</option>
#       <option value="kmeans_PEV">kmeans_PEV</option>
#       <option value="kmeans_PLR">kmeans_PLR</option>
#       <option value="kmeans_PLS">kmeans_PLS</option>
#       <option value="kmeans_POCH">kmeans_POCH</option>
#       <option value="kmeans_PRD">kmeans_PRD</option>
#       <option value="kmeans_PS">kmeans_PS</option>
#       <option value="kmeans_PSL">kmeans_PSL</option>
#       <option value="kmeans_PST">kmeans_PST</option>
#       <option value="kmeans_PVL">kmeans_PVL</option>
#       <option value="kmeans_Rep.">kmeans_Rep.</option>
#       <option value="kmeans_UDC">kmeans_UDC</option>
#       <option value="kmeans_UDF">kmeans_UDF</option>
# </select>
#
# var dict = {
#       "DBSCAN_AdI": "describe DBSCAN_AdI",
#       "DBSCAN_DS": "describe DBSCAN_DS",
#       "DBSCAN_Lega": "describe DBSCAN_Lega",
#       "DBSCAN_MCR": "describe DBSCAN_MCR",
#       "DBSCAN_PBD": "describe DBSCAN_PBD",
#       "DBSCAN_PCS": "describe DBSCAN_PCS",
#       "DBSCAN_PDC": "describe DBSCAN_PDC",
#       "DBSCAN_PES": "describe DBSCAN_PES",
#       "DBSCAN_PEV": "describe DBSCAN_PEV",
#       "DBSCAN_PLR": "describe DBSCAN_PLR",
#       "DBSCAN_PLS": "describe DBSCAN_PLS",
#       "DBSCAN_POCH": "describe DBSCAN_POCH",
#       "DBSCAN_PRD": "describe DBSCAN_PRD",
#       "DBSCAN_PS": "describe DBSCAN_PS",
#       "DBSCAN_PSL": "describe DBSCAN_PSL",
#       "DBSCAN_PST": "describe DBSCAN_PST",
#       "DBSCAN_PVL": "describe DBSCAN_PVL",
#       "DBSCAN_Rep.": "describe DBSCAN_Rep.",
#       "DBSCAN_UDC": "describe DBSCAN_UDC",
#       "DBSCAN_UDF": "describe DBSCAN_UDF",
#       "kmeans_AdI": "describe kmeans_AdI",
#       "kmeans_DS": "describe kmeans_DS",
#       "kmeans_Lega": "describe kmeans_Lega",
#       "kmeans_MCR": "describe kmeans_MCR",
#       "kmeans_PBD": "describe kmeans_PBD",
#       "kmeans_PCS": "describe kmeans_PCS",
#       "kmeans_PDC": "describe kmeans_PDC",
#       "kmeans_PES": "describe kmeans_PES",
#       "kmeans_PEV": "describe kmeans_PEV",
#       "kmeans_PLR": "describe kmeans_PLR",
#       "kmeans_PLS": "describe kmeans_PLS",
#       "kmeans_POCH": "describe kmeans_POCH",
#       "kmeans_PRD": "describe kmeans_PRD",
#       "kmeans_PS": "describe kmeans_PS",
#       "kmeans_PSL": "describe kmeans_PSL",
#       "kmeans_PST": "describe kmeans_PST",
#       "kmeans_PVL": "describe kmeans_PVL",
#       "kmeans_Rep.": "describe kmeans_Rep.",
#       "kmeans_UDC": "describe kmeans_UDC",
#       "kmeans_UDF": "describe kmeans_UDF",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/map_theme
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="map_Economy">map_Economy</option>
#       <option value="map_Education,culture,media">map_Education,culture,media</option>
#       <option value="map_Foreign policy">map_Foreign policy</option>
#       <option value="map_Infrastructure, planning, environment">map_Infrastructure, planning, environment</option>
#       <option value="map_Political regime">map_Political regime</option>
#       <option value="map_public finances">map_public finances</option>
#       <option value="map_security policy">map_security policy</option>
#       <option value="map_social policies">map_social policies</option>
# </select>
#
# var dict = {
#       "map_Economy": "describe map_Economy",
#       "map_Education,culture,media": "describe map_Education,culture,media",
#       "map_Foreign policy": "describe map_Foreign policy",
#       "map_Infrastructure, planning, environment": "describe map_Infrastructure, planning, environment",
#       "map_Political regime": "describe map_Political regime",
#       "map_public finances": "describe map_public finances",
#       "map_security policy": "describe map_security policy",
#       "map_social policies": "describe map_social policies",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/young/maps_theme_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="DBSCAN_Economy">DBSCAN_Economy</option>
#       <option value="DBSCAN_Education,culture,media">DBSCAN_Education,culture,media</option>
#       <option value="DBSCAN_Foreign policy">DBSCAN_Foreign policy</option>
#       <option value="DBSCAN_Infrastructure, planning, environment">DBSCAN_Infrastructure, planning, environment</option>
#       <option value="DBSCAN_Political regime">DBSCAN_Political regime</option>
#       <option value="DBSCAN_public finances">DBSCAN_public finances</option>
#       <option value="DBSCAN_security policy">DBSCAN_security policy</option>
#       <option value="DBSCAN_social policies">DBSCAN_social policies</option>
#       <option value="kmeans_Economy">kmeans_Economy</option>
#       <option value="kmeans_Education,culture,media">kmeans_Education,culture,media</option>
#       <option value="kmeans_Foreign policy">kmeans_Foreign policy</option>
#       <option value="kmeans_Infrastructure, planning, environment">kmeans_Infrastructure, planning, environment</option>
#       <option value="kmeans_Political regime">kmeans_Political regime</option>
#       <option value="kmeans_public finances">kmeans_public finances</option>
#       <option value="kmeans_security policy">kmeans_security policy</option>
#       <option value="kmeans_social policies">kmeans_social policies</option>
# </select>
#
# var dict = {
#       "DBSCAN_Economy": "describe DBSCAN_Economy",
#       "DBSCAN_Education,culture,media": "describe DBSCAN_Education,culture,media",
#       "DBSCAN_Foreign policy": "describe DBSCAN_Foreign policy",
#       "DBSCAN_Infrastructure, planning, environment": "describe DBSCAN_Infrastructure, planning, environment",
#       "DBSCAN_Political regime": "describe DBSCAN_Political regime",
#       "DBSCAN_public finances": "describe DBSCAN_public finances",
#       "DBSCAN_security policy": "describe DBSCAN_security policy",
#       "DBSCAN_social policies": "describe DBSCAN_social policies",
#       "kmeans_Economy": "describe kmeans_Economy",
#       "kmeans_Education,culture,media": "describe kmeans_Education,culture,media",
#       "kmeans_Foreign policy": "describe kmeans_Foreign policy",
#       "kmeans_Infrastructure, planning, environment": "describe kmeans_Infrastructure, planning, environment",
#       "kmeans_Political regime": "describe kmeans_Political regime",
#       "kmeans_public finances": "describe kmeans_public finances",
#       "kmeans_security policy": "describe kmeans_security policy",
#       "kmeans_social policies": "describe kmeans_social policies",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/young/map_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="DBSCAN">DBSCAN</option>
#       <option value="kmeans2">kmeans2</option>
#       <option value="kmeans3">kmeans3</option>
#       <option value="kmeans4">kmeans4</option>
#       <option value="kmeans5">kmeans5</option>
# </select>
#
# var dict = {
#       "DBSCAN": "describe DBSCAN",
#       "kmeans2": "describe kmeans2",
#       "kmeans3": "describe kmeans3",
#       "kmeans4": "describe kmeans4",
#       "kmeans5": "describe kmeans5",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/young/map_recommendation_cluster
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="DBSCAN_DS">DBSCAN_DS</option>
#       <option value="DBSCAN_Lega">DBSCAN_Lega</option>
#       <option value="DBSCAN_MCR">DBSCAN_MCR</option>
#       <option value="DBSCAN_PBD">DBSCAN_PBD</option>
#       <option value="DBSCAN_PCS">DBSCAN_PCS</option>
#       <option value="DBSCAN_PDC">DBSCAN_PDC</option>
#       <option value="DBSCAN_PES">DBSCAN_PES</option>
#       <option value="DBSCAN_PEV">DBSCAN_PEV</option>
#       <option value="DBSCAN_PLR">DBSCAN_PLR</option>
#       <option value="DBSCAN_PLS">DBSCAN_PLS</option>
#       <option value="DBSCAN_PRD">DBSCAN_PRD</option>
#       <option value="DBSCAN_PS">DBSCAN_PS</option>
#       <option value="DBSCAN_PSL">DBSCAN_PSL</option>
#       <option value="DBSCAN_PST">DBSCAN_PST</option>
#       <option value="DBSCAN_PVL">DBSCAN_PVL</option>
#       <option value="DBSCAN_UDC">DBSCAN_UDC</option>
#       <option value="DBSCAN_UDF">DBSCAN_UDF</option>
#       <option value="kmeans_DS">kmeans_DS</option>
#       <option value="kmeans_Lega">kmeans_Lega</option>
#       <option value="kmeans_MCR">kmeans_MCR</option>
#       <option value="kmeans_PBD">kmeans_PBD</option>
#       <option value="kmeans_PCS">kmeans_PCS</option>
#       <option value="kmeans_PDC">kmeans_PDC</option>
#       <option value="kmeans_PES">kmeans_PES</option>
#       <option value="kmeans_PEV">kmeans_PEV</option>
#       <option value="kmeans_PLR">kmeans_PLR</option>
#       <option value="kmeans_PLS">kmeans_PLS</option>
#       <option value="kmeans_PRD">kmeans_PRD</option>
#       <option value="kmeans_PS">kmeans_PS</option>
#       <option value="kmeans_PSL">kmeans_PSL</option>
#       <option value="kmeans_PST">kmeans_PST</option>
#       <option value="kmeans_PVL">kmeans_PVL</option>
#       <option value="kmeans_UDC">kmeans_UDC</option>
#       <option value="kmeans_UDF">kmeans_UDF</option>
# </select>
#
# var dict = {
#       "DBSCAN_DS": "describe DBSCAN_DS",
#       "DBSCAN_Lega": "describe DBSCAN_Lega",
#       "DBSCAN_MCR": "describe DBSCAN_MCR",
#       "DBSCAN_PBD": "describe DBSCAN_PBD",
#       "DBSCAN_PCS": "describe DBSCAN_PCS",
#       "DBSCAN_PDC": "describe DBSCAN_PDC",
#       "DBSCAN_PES": "describe DBSCAN_PES",
#       "DBSCAN_PEV": "describe DBSCAN_PEV",
#       "DBSCAN_PLR": "describe DBSCAN_PLR",
#       "DBSCAN_PLS": "describe DBSCAN_PLS",
#       "DBSCAN_PRD": "describe DBSCAN_PRD",
#       "DBSCAN_PS": "describe DBSCAN_PS",
#       "DBSCAN_PSL": "describe DBSCAN_PSL",
#       "DBSCAN_PST": "describe DBSCAN_PST",
#       "DBSCAN_PVL": "describe DBSCAN_PVL",
#       "DBSCAN_UDC": "describe DBSCAN_UDC",
#       "DBSCAN_UDF": "describe DBSCAN_UDF",
#       "kmeans_DS": "describe kmeans_DS",
#       "kmeans_Lega": "describe kmeans_Lega",
#       "kmeans_MCR": "describe kmeans_MCR",
#       "kmeans_PBD": "describe kmeans_PBD",
#       "kmeans_PCS": "describe kmeans_PCS",
#       "kmeans_PDC": "describe kmeans_PDC",
#       "kmeans_PES": "describe kmeans_PES",
#       "kmeans_PEV": "describe kmeans_PEV",
#       "kmeans_PLR": "describe kmeans_PLR",
#       "kmeans_PLS": "describe kmeans_PLS",
#       "kmeans_PRD": "describe kmeans_PRD",
#       "kmeans_PS": "describe kmeans_PS",
#       "kmeans_PSL": "describe kmeans_PSL",
#       "kmeans_PST": "describe kmeans_PST",
#       "kmeans_PVL": "describe kmeans_PVL",
#       "kmeans_UDC": "describe kmeans_UDC",
#       "kmeans_UDF": "describe kmeans_UDF",
#       };
#
#
#
# _______________
#
# ../docs/assets/data/young
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# </select>
#
# var dict = {
#       };
#
#
#
# _______________
#
# ../docs/assets/data
#
# <select onchange="theThingToDoIfItChange()" id="selection">
#       <option value="map_language">map_language</option>
# </select>
#
# var dict = {
#       "map_language": "describe map_language",
#       };
#
#
#
# _______________
