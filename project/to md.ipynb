# %%
import os
import time
from selenium import webdriver



    


def iter_png (path) :
    names = []
    for fn in os.listdir(path):
         if  os.path.isfile(path+'/'+fn)  :
            if fn.split('.')[-1]=='html' :
                names+=[fn]
         else :
            if path =='.' :
                iter_png (fn)
            else :
                iter_png (path+'/'+fn)
    str = path+'\n\n'
    str += ('<select onchange="theThingToDoIfItChange()" id="selection">\n')
    for n in names :
        str += '<option value="'+n+'+">'+n+'</option>\n'
    str += '</select>\n\n'
    
    str+='var dict = {\n'
    for n in names :
        str += n+': ""'+'\n'
    str += '};\n\n\n\n_______________\n'
    print (str)
         
iter_png('../docs/assets/data')
# Out:
# ../docs/assets/data/maps_partis
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="map_AdI.html+">map_AdI.html</option>
# <option value="map_DS.html+">map_DS.html</option>
# <option value="map_Lega.html+">map_Lega.html</option>
# <option value="map_MCR.html+">map_MCR.html</option>
# <option value="map_PBD.html+">map_PBD.html</option>
# <option value="map_PCS.html+">map_PCS.html</option>
# <option value="map_PDC.html+">map_PDC.html</option>
# <option value="map_PES.html+">map_PES.html</option>
# <option value="map_PEV.html+">map_PEV.html</option>
# <option value="map_PLR.html+">map_PLR.html</option>
# <option value="map_PLS.html+">map_PLS.html</option>
# <option value="map_POCH.html+">map_POCH.html</option>
# <option value="map_PRD.html+">map_PRD.html</option>
# <option value="map_PS.html+">map_PS.html</option>
# <option value="map_PSL.html+">map_PSL.html</option>
# <option value="map_PST.html+">map_PST.html</option>
# <option value="map_PVL.html+">map_PVL.html</option>
# <option value="map_Rep..html+">map_Rep..html</option>
# <option value="map_UDC.html+">map_UDC.html</option>
# <option value="map_UDF.html+">map_UDF.html</option>
# </select>
#
# var dict = {
# map_AdI.html: ""
# map_DS.html: ""
# map_Lega.html: ""
# map_MCR.html: ""
# map_PBD.html: ""
# map_PCS.html: ""
# map_PDC.html: ""
# map_PES.html: ""
# map_PEV.html: ""
# map_PLR.html: ""
# map_PLS.html: ""
# map_POCH.html: ""
# map_PRD.html: ""
# map_PS.html: ""
# map_PSL.html: ""
# map_PST.html: ""
# map_PVL.html: ""
# map_Rep..html: ""
# map_UDC.html: ""
# map_UDF.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/maps_theme_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="DBSCAN_Economy.html+">DBSCAN_Economy.html</option>
# <option value="DBSCAN_Education,culture,media.html+">DBSCAN_Education,culture,media.html</option>
# <option value="DBSCAN_Foreign policy.html+">DBSCAN_Foreign policy.html</option>
# <option value="DBSCAN_Infrastructure, planning, environment.html+">DBSCAN_Infrastructure, planning, environment.html</option>
# <option value="DBSCAN_Political regime.html+">DBSCAN_Political regime.html</option>
# <option value="DBSCAN_public finances.html+">DBSCAN_public finances.html</option>
# <option value="DBSCAN_security policy.html+">DBSCAN_security policy.html</option>
# <option value="DBSCAN_social policies.html+">DBSCAN_social policies.html</option>
# <option value="kmeans_Economy.html+">kmeans_Economy.html</option>
# <option value="kmeans_Education,culture,media.html+">kmeans_Education,culture,media.html</option>
# <option value="kmeans_Foreign policy.html+">kmeans_Foreign policy.html</option>
# <option value="kmeans_Infrastructure, planning, environment.html+">kmeans_Infrastructure, planning, environment.html</option>
# <option value="kmeans_Political regime.html+">kmeans_Political regime.html</option>
# <option value="kmeans_public finances.html+">kmeans_public finances.html</option>
# <option value="kmeans_security policy.html+">kmeans_security policy.html</option>
# <option value="kmeans_social policies.html+">kmeans_social policies.html</option>
# </select>
#
# var dict = {
# DBSCAN_Economy.html: ""
# DBSCAN_Education,culture,media.html: ""
# DBSCAN_Foreign policy.html: ""
# DBSCAN_Infrastructure, planning, environment.html: ""
# DBSCAN_Political regime.html: ""
# DBSCAN_public finances.html: ""
# DBSCAN_security policy.html: ""
# DBSCAN_social policies.html: ""
# kmeans_Economy.html: ""
# kmeans_Education,culture,media.html: ""
# kmeans_Foreign policy.html: ""
# kmeans_Infrastructure, planning, environment.html: ""
# kmeans_Political regime.html: ""
# kmeans_public finances.html: ""
# kmeans_security policy.html: ""
# kmeans_social policies.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/map_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="DBSCAN.html+">DBSCAN.html</option>
# <option value="kmeans2.html+">kmeans2.html</option>
# <option value="kmeans3.html+">kmeans3.html</option>
# <option value="kmeans4.html+">kmeans4.html</option>
# <option value="kmeans5.html+">kmeans5.html</option>
# </select>
#
# var dict = {
# DBSCAN.html: ""
# kmeans2.html: ""
# kmeans3.html: ""
# kmeans4.html: ""
# kmeans5.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/map_recommendation_cluster
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="DBSCAN_AdI.html+">DBSCAN_AdI.html</option>
# <option value="DBSCAN_DS.html+">DBSCAN_DS.html</option>
# <option value="DBSCAN_Lega.html+">DBSCAN_Lega.html</option>
# <option value="DBSCAN_MCR.html+">DBSCAN_MCR.html</option>
# <option value="DBSCAN_PBD.html+">DBSCAN_PBD.html</option>
# <option value="DBSCAN_PCS.html+">DBSCAN_PCS.html</option>
# <option value="DBSCAN_PDC.html+">DBSCAN_PDC.html</option>
# <option value="DBSCAN_PES.html+">DBSCAN_PES.html</option>
# <option value="DBSCAN_PEV.html+">DBSCAN_PEV.html</option>
# <option value="DBSCAN_PLR.html+">DBSCAN_PLR.html</option>
# <option value="DBSCAN_PLS.html+">DBSCAN_PLS.html</option>
# <option value="DBSCAN_POCH.html+">DBSCAN_POCH.html</option>
# <option value="DBSCAN_PRD.html+">DBSCAN_PRD.html</option>
# <option value="DBSCAN_PS.html+">DBSCAN_PS.html</option>
# <option value="DBSCAN_PSL.html+">DBSCAN_PSL.html</option>
# <option value="DBSCAN_PST.html+">DBSCAN_PST.html</option>
# <option value="DBSCAN_PVL.html+">DBSCAN_PVL.html</option>
# <option value="DBSCAN_Rep..html+">DBSCAN_Rep..html</option>
# <option value="DBSCAN_UDC.html+">DBSCAN_UDC.html</option>
# <option value="DBSCAN_UDF.html+">DBSCAN_UDF.html</option>
# <option value="kmeans_AdI.html+">kmeans_AdI.html</option>
# <option value="kmeans_DS.html+">kmeans_DS.html</option>
# <option value="kmeans_Lega.html+">kmeans_Lega.html</option>
# <option value="kmeans_MCR.html+">kmeans_MCR.html</option>
# <option value="kmeans_PBD.html+">kmeans_PBD.html</option>
# <option value="kmeans_PCS.html+">kmeans_PCS.html</option>
# <option value="kmeans_PDC.html+">kmeans_PDC.html</option>
# <option value="kmeans_PES.html+">kmeans_PES.html</option>
# <option value="kmeans_PEV.html+">kmeans_PEV.html</option>
# <option value="kmeans_PLR.html+">kmeans_PLR.html</option>
# <option value="kmeans_PLS.html+">kmeans_PLS.html</option>
# <option value="kmeans_POCH.html+">kmeans_POCH.html</option>
# <option value="kmeans_PRD.html+">kmeans_PRD.html</option>
# <option value="kmeans_PS.html+">kmeans_PS.html</option>
# <option value="kmeans_PSL.html+">kmeans_PSL.html</option>
# <option value="kmeans_PST.html+">kmeans_PST.html</option>
# <option value="kmeans_PVL.html+">kmeans_PVL.html</option>
# <option value="kmeans_Rep..html+">kmeans_Rep..html</option>
# <option value="kmeans_UDC.html+">kmeans_UDC.html</option>
# <option value="kmeans_UDF.html+">kmeans_UDF.html</option>
# </select>
#
# var dict = {
# DBSCAN_AdI.html: ""
# DBSCAN_DS.html: ""
# DBSCAN_Lega.html: ""
# DBSCAN_MCR.html: ""
# DBSCAN_PBD.html: ""
# DBSCAN_PCS.html: ""
# DBSCAN_PDC.html: ""
# DBSCAN_PES.html: ""
# DBSCAN_PEV.html: ""
# DBSCAN_PLR.html: ""
# DBSCAN_PLS.html: ""
# DBSCAN_POCH.html: ""
# DBSCAN_PRD.html: ""
# DBSCAN_PS.html: ""
# DBSCAN_PSL.html: ""
# DBSCAN_PST.html: ""
# DBSCAN_PVL.html: ""
# DBSCAN_Rep..html: ""
# DBSCAN_UDC.html: ""
# DBSCAN_UDF.html: ""
# kmeans_AdI.html: ""
# kmeans_DS.html: ""
# kmeans_Lega.html: ""
# kmeans_MCR.html: ""
# kmeans_PBD.html: ""
# kmeans_PCS.html: ""
# kmeans_PDC.html: ""
# kmeans_PES.html: ""
# kmeans_PEV.html: ""
# kmeans_PLR.html: ""
# kmeans_PLS.html: ""
# kmeans_POCH.html: ""
# kmeans_PRD.html: ""
# kmeans_PS.html: ""
# kmeans_PSL.html: ""
# kmeans_PST.html: ""
# kmeans_PVL.html: ""
# kmeans_Rep..html: ""
# kmeans_UDC.html: ""
# kmeans_UDF.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/map_theme
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="map_Economy.html+">map_Economy.html</option>
# <option value="map_Education,culture,media.html+">map_Education,culture,media.html</option>
# <option value="map_Foreign policy.html+">map_Foreign policy.html</option>
# <option value="map_Infrastructure, planning, environment.html+">map_Infrastructure, planning, environment.html</option>
# <option value="map_Political regime.html+">map_Political regime.html</option>
# <option value="map_public finances.html+">map_public finances.html</option>
# <option value="map_security policy.html+">map_security policy.html</option>
# <option value="map_social policies.html+">map_social policies.html</option>
# </select>
#
# var dict = {
# map_Economy.html: ""
# map_Education,culture,media.html: ""
# map_Foreign policy.html: ""
# map_Infrastructure, planning, environment.html: ""
# map_Political regime.html: ""
# map_public finances.html: ""
# map_security policy.html: ""
# map_social policies.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/young/maps_theme_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="DBSCAN_Economy.html+">DBSCAN_Economy.html</option>
# <option value="DBSCAN_Education,culture,media.html+">DBSCAN_Education,culture,media.html</option>
# <option value="DBSCAN_Foreign policy.html+">DBSCAN_Foreign policy.html</option>
# <option value="DBSCAN_Infrastructure, planning, environment.html+">DBSCAN_Infrastructure, planning, environment.html</option>
# <option value="DBSCAN_Political regime.html+">DBSCAN_Political regime.html</option>
# <option value="DBSCAN_public finances.html+">DBSCAN_public finances.html</option>
# <option value="DBSCAN_security policy.html+">DBSCAN_security policy.html</option>
# <option value="DBSCAN_social policies.html+">DBSCAN_social policies.html</option>
# <option value="kmeans_Economy.html+">kmeans_Economy.html</option>
# <option value="kmeans_Education,culture,media.html+">kmeans_Education,culture,media.html</option>
# <option value="kmeans_Foreign policy.html+">kmeans_Foreign policy.html</option>
# <option value="kmeans_Infrastructure, planning, environment.html+">kmeans_Infrastructure, planning, environment.html</option>
# <option value="kmeans_Political regime.html+">kmeans_Political regime.html</option>
# <option value="kmeans_public finances.html+">kmeans_public finances.html</option>
# <option value="kmeans_security policy.html+">kmeans_security policy.html</option>
# <option value="kmeans_social policies.html+">kmeans_social policies.html</option>
# </select>
#
# var dict = {
# DBSCAN_Economy.html: ""
# DBSCAN_Education,culture,media.html: ""
# DBSCAN_Foreign policy.html: ""
# DBSCAN_Infrastructure, planning, environment.html: ""
# DBSCAN_Political regime.html: ""
# DBSCAN_public finances.html: ""
# DBSCAN_security policy.html: ""
# DBSCAN_social policies.html: ""
# kmeans_Economy.html: ""
# kmeans_Education,culture,media.html: ""
# kmeans_Foreign policy.html: ""
# kmeans_Infrastructure, planning, environment.html: ""
# kmeans_Political regime.html: ""
# kmeans_public finances.html: ""
# kmeans_security policy.html: ""
# kmeans_social policies.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/young/map_ml
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="DBSCAN.html+">DBSCAN.html</option>
# <option value="kmeans2.html+">kmeans2.html</option>
# <option value="kmeans3.html+">kmeans3.html</option>
# <option value="kmeans4.html+">kmeans4.html</option>
# <option value="kmeans5.html+">kmeans5.html</option>
# </select>
#
# var dict = {
# DBSCAN.html: ""
# kmeans2.html: ""
# kmeans3.html: ""
# kmeans4.html: ""
# kmeans5.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/young/map_recommendation_cluster
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="DBSCAN_DS.html+">DBSCAN_DS.html</option>
# <option value="DBSCAN_Lega.html+">DBSCAN_Lega.html</option>
# <option value="DBSCAN_MCR.html+">DBSCAN_MCR.html</option>
# <option value="DBSCAN_PBD.html+">DBSCAN_PBD.html</option>
# <option value="DBSCAN_PCS.html+">DBSCAN_PCS.html</option>
# <option value="DBSCAN_PDC.html+">DBSCAN_PDC.html</option>
# <option value="DBSCAN_PES.html+">DBSCAN_PES.html</option>
# <option value="DBSCAN_PEV.html+">DBSCAN_PEV.html</option>
# <option value="DBSCAN_PLR.html+">DBSCAN_PLR.html</option>
# <option value="DBSCAN_PLS.html+">DBSCAN_PLS.html</option>
# <option value="DBSCAN_PRD.html+">DBSCAN_PRD.html</option>
# <option value="DBSCAN_PS.html+">DBSCAN_PS.html</option>
# <option value="DBSCAN_PSL.html+">DBSCAN_PSL.html</option>
# <option value="DBSCAN_PST.html+">DBSCAN_PST.html</option>
# <option value="DBSCAN_PVL.html+">DBSCAN_PVL.html</option>
# <option value="DBSCAN_UDC.html+">DBSCAN_UDC.html</option>
# <option value="DBSCAN_UDF.html+">DBSCAN_UDF.html</option>
# <option value="kmeans_DS.html+">kmeans_DS.html</option>
# <option value="kmeans_Lega.html+">kmeans_Lega.html</option>
# <option value="kmeans_MCR.html+">kmeans_MCR.html</option>
# <option value="kmeans_PBD.html+">kmeans_PBD.html</option>
# <option value="kmeans_PCS.html+">kmeans_PCS.html</option>
# <option value="kmeans_PDC.html+">kmeans_PDC.html</option>
# <option value="kmeans_PES.html+">kmeans_PES.html</option>
# <option value="kmeans_PEV.html+">kmeans_PEV.html</option>
# <option value="kmeans_PLR.html+">kmeans_PLR.html</option>
# <option value="kmeans_PLS.html+">kmeans_PLS.html</option>
# <option value="kmeans_PRD.html+">kmeans_PRD.html</option>
# <option value="kmeans_PS.html+">kmeans_PS.html</option>
# <option value="kmeans_PSL.html+">kmeans_PSL.html</option>
# <option value="kmeans_PST.html+">kmeans_PST.html</option>
# <option value="kmeans_PVL.html+">kmeans_PVL.html</option>
# <option value="kmeans_UDC.html+">kmeans_UDC.html</option>
# <option value="kmeans_UDF.html+">kmeans_UDF.html</option>
# </select>
#
# var dict = {
# DBSCAN_DS.html: ""
# DBSCAN_Lega.html: ""
# DBSCAN_MCR.html: ""
# DBSCAN_PBD.html: ""
# DBSCAN_PCS.html: ""
# DBSCAN_PDC.html: ""
# DBSCAN_PES.html: ""
# DBSCAN_PEV.html: ""
# DBSCAN_PLR.html: ""
# DBSCAN_PLS.html: ""
# DBSCAN_PRD.html: ""
# DBSCAN_PS.html: ""
# DBSCAN_PSL.html: ""
# DBSCAN_PST.html: ""
# DBSCAN_PVL.html: ""
# DBSCAN_UDC.html: ""
# DBSCAN_UDF.html: ""
# kmeans_DS.html: ""
# kmeans_Lega.html: ""
# kmeans_MCR.html: ""
# kmeans_PBD.html: ""
# kmeans_PCS.html: ""
# kmeans_PDC.html: ""
# kmeans_PES.html: ""
# kmeans_PEV.html: ""
# kmeans_PLR.html: ""
# kmeans_PLS.html: ""
# kmeans_PRD.html: ""
# kmeans_PS.html: ""
# kmeans_PSL.html: ""
# kmeans_PST.html: ""
# kmeans_PVL.html: ""
# kmeans_UDC.html: ""
# kmeans_UDF.html: ""
# };
#
#
#
# _______________
#
# ../docs/assets/data/young
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# </select>
#
# var dict = {
# };
#
#
#
# _______________
#
# ../docs/assets/data
#
# <select onchange="theThingToDoIfItChange()" id="selection">
# <option value="map_language.html+">map_language.html</option>
# </select>
#
# var dict = {
# map_language.html: ""
# };
#
#
#
# _______________
